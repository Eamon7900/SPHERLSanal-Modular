# %% [markdown]
# <h3> Enter Fileranges in fileRanges array below: </h3>

# %%
#Read in data, import modules, this cell needs to be run once for each data set
fileRanges = ["RRLHighV_t[924351-1682459]"]

# %run DataParser.py #A python file with classes to parse and store data from a range of ModelDumps
dataSet = DataSet(fileRanges)
# Out:
# TimeArray: [3542411.585777481]
# TimeArray: [3542411.585777481, 6177317.964275703]
# TimeArray: [3542411.585777481, 6177317.964275703, 6179321.023313478]
# TimeArray: [3542411.585777481, 6177317.964275703, 6179321.023313478, 6181323.0350053245]
# TimeArray: [3542411.585777481, 6177317.964275703, 6179321.023313478, 6181323.0350053245, 6183324.298773902]

# %% [markdown]
# <h3>  Variables </h3>
# <table style="width:100%">
#     <tr>
#         <th> Variable Identifier</th>
#         <th> Units </th>
#         <th> Variable Description </th>
# 	</tr>
# 	<tr>
# 		<td>M_r_im1half</td>
# 		<td>[g]</td>
# 		<td>Mass inside radial shell (cumulative)</td>
# 	</tr>
# 	<tr>
# 		<td>DM_r</td>
# 		<td>[g]</td>
# 		<td>Mass of a particular radial shell</td>
#
# 	</tr>
# 	<tr>
# 		<td>ErrorDM_r</td>
# 		<td></td>
# 		<td>Uncertainty of mass</td>
#
# 	</tr>
# 	<tr>
# 		<td>R_im1half</td>
# 		<td>[cm]</td>
# 		<td>radius at outer zone boundary</td>
#
# 	</tr>
# 	<tr>
# 		<td>R_ip1half</td>
# 		<td>[cm]</td>
# 		<td>radius at inner zone boundary</td>
# 	</tr>
# 	<tr>
# 		<td>&lt;D&gt;</td>
# 		<td>[g/cm^3]</td>
# 		<td>Average density in a radial shell</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_max </td>
# 		<td>[g/cm^3]</td>
# 		<td>Maximum density in a radial shell</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_max_j</td>
# 		<td></td>
# 		<td>Maximum density in theta direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_max_k</td>
# 		<td></td>
# 		<td>Maximum density in phi direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_min</td>
# 		<td>[g/cm^3]</td>
# 		<td>Minimum density</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_min_j</td>
# 		<td></td>
# 		<td>Minimum density in theta direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>D_min_k</td>
# 		<td></td>
# 		<td>Minimum density in phi direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>U_ave_im1half</td>
# 		<td>[cm/s]</td>
# 		<td>Average radial velocity at outer zone boundary</td>
#
# 	</tr>
# 	<tr>
# 		<td>U_max_im1half</td>
# 		<td>[cm/s]</td>
# 		<td>Average radial velocity at inner zone boundary</td>
#
# 	</tr>
# 	<tr>
# 		<td>U_max_j</td>
# 		<td></td>
# 		<td>Maximum radial velocity in theta direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>U_max_k</td>
# 		<td></td>
# 		<td>Maximum radial velocity in phi direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>U_min_im1half</td>
# 		<td>[cm/s]</td>
# 		<td>Minimum radial velocity at outer zone boundary</td>
# 	</tr>
# 	<tr>
# 		<td>U_min_j</td>
# 		<td></td>
# 		<td>Minimum radial velocity at outer zone boundary in theta direction</td>
# 	</tr>
# 	<tr>
# 		<td>U_min_k</td>
# 		<td></td>
# 		<td>Minimum radial velocity at outer zone boundary in phi direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>U0</td>
# 		<td>[cm/s]</td>
# 		<td>Grid velocity in the radial direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>V_ave</td>
# 		<td>[cm/s]</td>
# 		<td>Average theta velocity</td>
#
# 	</tr>
# 	<tr>
# 		<td>V_max</td>
# 		<td>[cm/s]</td>
# 		<td>Maximum theta velocity</td>
#
# 	</tr>
# 	<tr>
# 		<td>V_max_j</td>
# 		<td></td>
# 		<td>Maximum theta velocity in the theta direction</td>
#
# 	</tr>
# 	<tr>
# 		<td>V_max_k</td>
# 		<td></td>
# 		<td>Maximum theta velocity in the phi direction</td>
# 	</tr>
# 	<tr>
# 		<td>V_min</td>
# 		<td>[cm/s]</td>
# 		<td>Minimum theta velocity</td>
# 	</tr>
# 	<tr>
# 		<td>V_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>V_min_k</td>
# 		<td></td>
# 		<td></td>
# 	</tr>
# 	<tr>
# 		<td>W_ave</td>
# 		<td>[cm/s]</td>
# 		<td>Average phi velocity</td>
# 	</tr>
# 	<tr>
# 		<td>W_max</td>
# 		<td>[cm/s]</td>
# 		<td>Maximum phi velocity</td>
#
# 	</tr>
# 	<tr>
# 		<td>W_max_j</td>
# 		<td>[cm/s]</td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>W_max_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>W_min</td>
# 		<td>[cm/s]</td>
# 		<td>Minimum phi velocity</td>
#
# 	</tr>
# 	<tr>
# 		<td>W_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>W_min_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q</td>
# 		<td>[dynes/cm^2]</td>
# 		<td>? Some kind of work with units of pressure?</td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_max</td>
# 		<td>[dynes/cm^2]</td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_max_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_max_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_min</td>
# 		<td>[dynes/cm^2]</td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Q_min_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>E_ave</td>
# 		<td>[erg/g]</td>
# 		<td>Average energy per unit mass</td>
#
# 	</tr>
# 	<tr>
# 		<td>E_max</td>
# 		<td>[erg/g]</td>
# 		<td>Maximum energy per unit mass</td>
#
# 	</tr>
# 	<tr>
# 		<td>E_max_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>E_max_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>E_min</td>
# 		<td>[erg/g]</td>
# 		<td>Minimum energy per unit mass</td>
#
# 	</tr>
# 	<tr>
# 		<td>E_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>E_min_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>T_ave</td>
# 		<td>[k]</td>
# 		<td>Average temperature</td>
# 	</tr>
# 	<tr>
# 		<td>T_max</td>
# 		<td>[k]</td>
# 		<td>Maximum temperature</td>
# 	</tr>
# 	<tr>
# 		<td>T_max_j</td>
# 		<td></td>
# 		<td></td>
# 	</tr>
# 	<tr>
# 		<td>T_max_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>T_min</td>
# 		<td>[k]</td>
# 		<td>Minimum temperature</td>
#
# 	</tr>
# 	<tr>
# 		<td>T_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>T_min_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>Kap_ave</td>
# 		<td>[cm^2/g]</td>
# 		<td>Average opacity</td>
#
# 	</tr>
# 	<tr>
# 		<td>Kap_min</td>
# 		<td>[cm^2/g]</td>
# 		<td>Minimum opacity</td>
#
# 	</tr>
# 	<tr>
# 		<td>Kap_max</td>
# 		<td>[cm^2/g]</td>
# 		<td>Maximum opacity</td>
#
# 	</tr>
# 	<tr>
# 		<td>L_rd_im1half</td>
# 		<td>[L_sun]</td>
# 		<td>Radiative luminosity</td>
#
# 	</tr>
# 	<tr>
# 		<td>L_cv_im1half</td>
# 		<td>[L_sun]</td>
# 		<td>Convective luminosity</td>
#
# 	</tr>
# 	<tr>
# 		<td>F_cv_ave</td>
# 		<td>[L_sun/cm^2]</td>
# 		<td>Average convective flux</td>
#
# 	</tr>
# 	<tr>
# 		<td>F_cv_max</td>
# 		<td>[L_sun/cm^2]</td>
# 		<td>Maximum convective flux</td>
# 	</tr>
# 	<tr>
# 		<td>F_cv_min</td>
# 		<td>[L_sun/cm^2]</td>
# 		<td>Minimum convective flux</td>
# 	</tr>
# 	<tr>
# 		<td>KEP</td>
# 		<td>[ergs]</td>
# 		<td>Kinetic energy</td>
# 	</tr>
# 	<tr>
# 		<td>KETot</td>
# 		<td>[ergs]</td>
# 		<td>Total kinetic pressure</td>
#
# 	</tr>
# 	<tr>
# 		<td>P_ave</td>
# 		<td>[dynes/cm^2]</td>
# 		<td>Average pressure</td>
# 	</tr>
# 	<tr>
# 		<td>P_min</td>
# 		<td>[dynes/cm^2]</td>
# 		<td>Minimum pressure</td>
#
# 	</tr>
# 	<tr>
# 		<td>P_max</td>
# 		<td>[dynes/cm^2]</td>
# 		<td>Maximum pressure</td>
#
# 	</tr>
# 	<tr>
# 		<td>Gam_ave</td>
# 		<td>[na]</td>
# 		<td>Average adiabatic gamma (ratio of heat capacities)</td>
#
# 	</tr>
# 	<tr>
# 		<td>Gam_min</td>
# 		<td>[na]</td>
# 		<td>Minimum adiabatic gamma</td>
# 	</tr>
# 	<tr>
# 		<td>Gam_max</td>
# 		<td>[na]</td>
# 		<td>Maximum adiabatic gamma</td>
# 	</tr>
# 	<tr>
# 		<td>C_ave</td>
# 		<td>[cm/s]</td>
# 		<td>Average sound speed</td>
# 	</tr>
# 	<tr>
# 		<td>C_max</td>
# 		<td>[cm/s]</td>
# 		<td>Maximum sound speed</td>
# 	</tr>
# 	<tr>
# 		<td>C_max_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>C_max_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>C_min</td>
# 		<td>[cm/s]</td>
# 		<td>Minimum sound speed</td>
#
# 	</tr>
# 	<tr>
# 		<td>C_min_j</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>C_min_k</td>
# 		<td></td>
# 		<td></td>
#
# 	</tr>
# 	<tr>
# 		<td>UpFillFac</td>
# 		<td></td>
# 		<td>Fraction by area where material is moving radially outward</td>
# 	</tr>
# </table>
#
# <h3> Enter the variable identifier(s) and zone number(s) you wish to plot into the arrays at the top of the cell below </h3>

# %%
# Input plot data here: ##########################################################################################
vars=["U0", "DM_r"] #The list of variables to be plotted against time.  Each will have its own figure:
zones=[5, 5, 7, 9, 11] #The list of zone numbers you would like to plot for each variable (The first zone doesn't plot for some reason, so just enter it twice):
timeTrim = 1 #How many time steps to trim from plot: 
##################################################################################################################

from matplotlib import pyplot as plt #Plot using pyplot
# %run plots.py #A class to store colors, markers, and units for plots

figCount = 1
for var in vars:
    figCount += 1
    plt.figure(figCount)
    plt.title(var + plots.units.get(var, ""))
    plt.ylabel(var + plots.units.get(var, ""))
    plt.xlabel("Time [s]")
    colors = plots.colors.copy()
    markers = plots.markers.copy()
    for zone in zones:
        varData = {
            "times" : [],
            "values" : []
        }
        timeCount = 0
        for modelDump in dataSet.data:
            timeCount += 1
            if timeCount <= timeTrim : continue

            varData["times"].append(modelDump.time)
            varData["values"].append(modelDump.grid[zone - 1][var])

        #If either the colors or the markers array is empty refill them
        print(markers)
        if not colors: colors = plots.colors.copy()
        if not markers: markers = plots.markers.copy()
        #Plot the time series of the current zone
        plt.plot(varData["times"], varData["values"], color=colors.pop(), marker=markers.pop(), label=str("Zone: " + str(zone)))
# Out:
# ['.', '*', 'v', 'P', '+', 'x']
# ['.', '*', 'v', 'P', '+']
# ['.', '*', 'v', 'P']
# ['.', '*', 'v']
# ['.', '*']
# ['.']
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-4f919bd022af> in <module>
#      35         if not markers: markers = plots.markers
#      36         #Plot the time series of the current zone
# ---> 37         plt.plot(varData["times"], varData["values"], color=colors.pop(), marker=markers.pop(), label=str("Zone: " + str(zone)))
#      38
#      39
#
# IndexError: pop from empty list
